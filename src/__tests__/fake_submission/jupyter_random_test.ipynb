# %% [markdown]
# # This is an example of a jupyter notebook
#
# ```python
# print("Hello, world!")
# ```
#
# The following is a test of different ways we can display code

# %%
# normal import statement for built 
import os
os.environ

# %%
# The following should fail 
os.environ()

# %%
# testing printing the output 
print(os.environ)

# %%
import sklearn
print(sklearn.__version__)

data = [1, 2, 3, 4, 5]
print(data)

# %%
import matplotlib.pyplot as plt

plt.plot(data)
plt.title("Line Chart of Data")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
import pandas as pd

numbers_df = pd.DataFrame({'Number': range(1, 11)})
print(numbers_df)

# %% [markdown]
# # Next testing if we can do imports and file operations

# %%
import os
print(os.listdir('.'))


open('test_file.txt', 'w').write('This is a test file.')
print(os.listdir('.'))

# %%
f = open('test_file.txt', 'r').read()
print(f)

# %%
f = open('non_existent_file.txt', 'r').read()
print(f)

# %%
f = open('included_file.txt', 'r').read()
print(f)

# %% [markdown]
# # Test if we can import a dataset from ~/shared/

# %%
import pandas as pd
import os
data = pd.read_csv(os.path.expanduser('~/shared/data_1.csv'))
print(data.head())

# %%
import pandas as pd
import os
data = pd.read_csv(os.path.expanduser('~/shared/data.csv'))
print(data.head())

# %%
import pandas as pd
import os
data = pd.read_csv(os.path.expanduser('~/shared/data.csv'))

# check the likelyhood of more comedy than drama

print(data['genre'].value_counts())

# %% [markdown]
# ## Test absoulte paths

# %%
# Check if /srv/share exists
print(os.path.exists('/srv/share'))

# %%
# Test if we can read from /srv/share/test/data.csv
data = pd.read_csv('/srv/share/test/data.csv')
print(data.head())

# %%
# !pip install pandas numpy matplotlib

# %% [markdown]
# # We should not be able to write to /root/.cache/pip

# %%
# writing to pip cache should fail
open('/root/.cache/pip/test_cache_file.txt', 'w').write('This should fail.')
print(os.listdir('/root/.cache/pip'))
