# %% [markdown]
# # PHP Starter Notebook
# Complete TODO sections for parsing, file I/O, and rendering output.

# %%
<?php
function parse_numbers(string $csv_line): array {
  // TODO(student): parse comma-separated integers
  return [];
}

# %%
// TODO(student): read ../existing_data.txt and write starter_output.txt
// TODO(student): print a render table to stdout
// assert(count($values) > 0);
