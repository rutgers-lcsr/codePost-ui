// %% [markdown]
// # C++ Starter Notebook
// Implement parsing logic, keep file I/O, and make the assertion pass.

// %%
#include <vector>
#include <string>

std::vector<int> parse_numbers(const std::string& csv_line) {
    // TODO(student): parse comma-separated integers
    return {};
}

// %%
// TODO(student): read shared/existing_data.txt and write starter_output.txt
// TODO(student): print render text block to stdout
// assert(!values.empty());
