// %% [markdown]
// # Node.js Starter Notebook
// Implement parser logic and render-friendly output.

// %%
function parseNumbers(csvLine) {
  // TODO(student): parse comma-separated integers
  return [];
}

// %%
// TODO(student): read shared/existing_data.txt and write starter_output.txt
// TODO(student): print a table to stdout for rendering tests
// throw new Error('intentional starter failure until completed');
