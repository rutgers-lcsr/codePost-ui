# %% [markdown]
# # R Starter Notebook
# Implement parser and plotting logic while preserving I/O + assertion flow.

# %%
parse_numbers <- function(csv_line) {
  # TODO(student): parse comma-separated numeric values
  numeric(0)
}

# %%
# TODO(student): read ../existing_data.txt
# TODO(student): write starter_output.txt and print render table
# TODO(student): generate a simple plot
stopifnot('Starter assertion intentionally triggers until completed.' = FALSE)
