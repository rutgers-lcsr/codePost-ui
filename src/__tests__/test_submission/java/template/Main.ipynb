# %% [markdown]
# # Java Starter Notebook
# Complete parsing and rendering TODOs, then make assertions pass.

# %%
import java.util.Collections;
import java.util.List;

List<Integer> parseNumbers(String csvLine) {
    // TODO(student): parse comma-separated integers
    return Collections.emptyList();
}

# %%
// TODO(student): read ../existing_data.txt and write starter_output.txt
// TODO(student): print a rendering table to stdout
// assert !values.isEmpty();
