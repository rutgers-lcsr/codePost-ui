# %% [markdown]
# # Ruby Starter Notebook
# Implement parser and rendering TODOs while preserving assertion flow.

# %%
def parse_numbers(csv_line)
  # TODO(student): parse comma-separated integers
  []
end

# %%
# TODO(student): read shared/existing_data.txt and write starter_output.txt
# TODO(student): print render table to stdout
raise 'Starter assertion intentionally triggers until completed.'
