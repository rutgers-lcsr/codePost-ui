# %% [markdown]
# # Python Starter Notebook
# Implement parser + plotting TODOs and preserve file I/O + assertion flow.

# %%
from pathlib import Path
import matplotlib.pyplot as plt

def parse_numbers(csv_line: str) -> list[int]:
    # TODO(student): parse comma-separated integers
    return []

# %%
# TODO(student): read ../existing_data.txt
# TODO(student): write starter_output.txt and print render lines
# TODO(student): plot values
assert False, 'Starter assertion intentionally triggers until completed.'
